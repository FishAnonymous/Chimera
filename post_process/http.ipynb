# %% [markdown]
# # HTTP

# %%
import os 
import pandas as pd
import json
from tqdm import tqdm

scenario = "Tech-Company"
company_type_member = "tech_company"
company_type = "tech"

# scenario = "Finance-Company"
# company_type_member = "finance_corporation"
# company_type = "finance"

root_dir = "/data2/visitor/ASE25/Chimera"

output_dir = f"{root_dir}/Final-Output/{company_type_member}/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

output_csv = f'{output_dir}/{company_type}_http.csv'

# read the csv
df = pd.read_csv(output_csv)

# %%
len(df)
# Out:
# 9570

# %%
with open ("/data2/visitor/ASE25/Chimera/demo/attack_logs/gen_attack_4_medical_institution/mrs-2/mrs-2_week_1_Friday_executio_task_21.log", "r") as f:
    # the file is 6G sized, read only the first 1000 lines
    lines = f.readlines()[50:]

# %%
lines
